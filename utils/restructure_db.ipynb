# %% [markdown]
# # Data restructuring
# ## This is meant as a temporary workflow to restructure
# ## This will changed when a stable version is produced which is:
# ### These requirements are:
# ### - Create a matrix collection of SNP data
# ### - Create a new collection variant sample data

# %%
# imports appropiate packages
import pandas as pd
import numpy as np
import pymongo

# %%
db = pymongo.MongoClient('localhost',27017).sarscov2_standalone

# %%
samples = [x for x in db.sample.find()]
variants = [x for x in db.variant.find()]
depth = [x for x in db.depth.find()]

# %%
depth
# Out:
# [{'_id': ObjectId('6294b9ffc3d5743c5c7519a1'),
#   'pos': 35,
#   'sample_id': 'sc2-1001',
#   'dp': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a2'),
#   'sample_id': 'sc2-1001',
#   'pos': 103,
#   'dp': 3602,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 3602,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a3'),
#   'A': 1,
#   'REFSKIP': 0,
#   'dp': 5085,
#   'pos': 204,
#   'sample_id': 'sc2-1001',
#   'G': 2,
#   'DEL': 0,
#   'T': 5081,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a4'),
#   'dp': 5061,
#   'sample_id': 'sc2-1001',
#   'pos': 222,
#   'A': 1,
#   'REFSKIP': 0,
#   'T': 2,
#   'C': 5058,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a5'),
#   'G': 2,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 4733,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 241,
#   'dp': 4735},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a6'),
#   'G': 2,
#   'DEL': 0,
#   'T': 4,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 15421,
#   'REFSKIP': 0,
#   'A': 2,
#   'dp': 15429,
#   'sample_id': 'sc2-1001',
#   'pos': 398},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a7'),
#   'DEL': 0,
#   'G': 0,
#   'C': 21582,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 3,
#   'A': 5,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 445,
#   'dp': 21590},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a8'),
#   'dp': 22632,
#   'pos': 539,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 1,
#   'T': 3,
#   'C': 22627,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519a9'),
#   'T': 23310,
#   'C': 6,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 2,
#   'G': 4,
#   'dp': 23323,
#   'sample_id': 'sc2-1001',
#   'pos': 593,
#   'A': 1,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519aa'),
#   'pos': 682,
#   'sample_id': 'sc2-1001',
#   'dp': 16191,
#   'A': 3,
#   'REFSKIP': 0,
#   'C': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 16166,
#   'DEL': 0,
#   'G': 19},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ab'),
#   'G': 2,
#   'DEL': 0,
#   'T': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 14646,
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 14651,
#   'pos': 799,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ac'),
#   'DEL': 0,
#   'G': 1,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 11,
#   'REFSKIP': 0,
#   'A': 13376,
#   'pos': 905,
#   'sample_id': 'sc2-1001',
#   'dp': 13389},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ad'),
#   'G': 1,
#   'DEL': 0,
#   'T': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 12642,
#   'A': 7,
#   'REFSKIP': 0,
#   'dp': 12653,
#   'pos': 913,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ae'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4,
#   'T': 4,
#   'REFSKIP': 0,
#   'A': 12192,
#   'pos': 919,
#   'sample_id': 'sc2-1001',
#   'dp': 12200},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519af'),
#   'A': 22528,
#   'REFSKIP': 0,
#   'dp': 22540,
#   'pos': 1064,
#   'sample_id': 'sc2-1001',
#   'DEL': 0,
#   'G': 7,
#   'T': 5,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b0'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 21857,
#   'T': 2,
#   'G': 4,
#   'DEL': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 1179,
#   'dp': 21867,
#   'A': 4,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b1'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 581,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 581,
#   'sample_id': 'sc2-1001',
#   'pos': 1513},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b2'),
#   'dp': 485,
#   'sample_id': 'sc2-1001',
#   'pos': 1549,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 485,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b3'),
#   'dp': 4590,
#   'sample_id': 'sc2-1001',
#   'pos': 1684,
#   'A': 1,
#   'REFSKIP': 0,
#   'T': 1,
#   'C': 4588,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b4'),
#   'sample_id': 'sc2-1001',
#   'pos': 1887,
#   'dp': 2959,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2,
#   'T': 2955,
#   'G': 2,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b5'),
#   'DEL': 0,
#   'G': 0,
#   'C': 194,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 2048,
#   'sample_id': 'sc2-1001',
#   'dp': 194},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b6'),
#   'DEL': 0,
#   'G': 0,
#   'C': 199,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 2061,
#   'dp': 199},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b7'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 194,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 194,
#   'pos': 2110,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b8'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 189,
#   'sample_id': 'sc2-1001',
#   'pos': 2119,
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 189,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519b9'),
#   'T': 186,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 186,
#   'sample_id': 'sc2-1001',
#   'pos': 2137,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ba'),
#   'pos': 2143,
#   'sample_id': 'sc2-1001',
#   'dp': 170,
#   'REFSKIP': 0,
#   'A': 0,
#   'C': 170,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519bb'),
#   'DEL': 0,
#   'G': 0,
#   'C': 3449,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'A': 2,
#   'REFSKIP': 0,
#   'pos': 2268,
#   'sample_id': 'sc2-1001',
#   'dp': 3451},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519bc'),
#   'sample_id': 'sc2-1001',
#   'pos': 2416,
#   'dp': 4713,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4712,
#   'T': 0,
#   'G': 1,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519bd'),
#   'dp': 3507,
#   'pos': 2510,
#   'sample_id': 'sc2-1001',
#   'A': 2,
#   'REFSKIP': 0,
#   'T': 0,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 3504},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519be'),
#   'T': 0,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 1,
#   'pos': 2668,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519bf'),
#   'DEL': 0,
#   'G': 3,
#   'C': 7610,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1,
#   'A': 3,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 2997,
#   'dp': 7617},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c0'),
#   'A': 1,
#   'REFSKIP': 0,
#   'dp': 6980,
#   'pos': 3037,
#   'sample_id': 'sc2-1001',
#   'DEL': 7,
#   'G': 0,
#   'T': 6970,
#   'C': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c1'),
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 6103,
#   'DEL': 0,
#   'dp': 6104,
#   'sample_id': 'sc2-1001',
#   'pos': 3114,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c2'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 3259,
#   'sample_id': 'sc2-1001',
#   'dp': 5163,
#   'DEL': 0,
#   'G': 5160,
#   'C': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c3'),
#   'pos': 3267,
#   'sample_id': 'sc2-1001',
#   'dp': 5517,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 5517,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c4'),
#   'G': 1,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 6083,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 6084,
#   'sample_id': 'sc2-1001',
#   'pos': 3311},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c5'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 3397,
#   'dp': 5660,
#   'DEL': 0,
#   'G': 1,
#   'C': 5659,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c6'),
#   'T': 0,
#   'C': 1262,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 1262,
#   'pos': 3602,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c7'),
#   'dp': 1273,
#   'sample_id': 'sc2-1001',
#   'pos': 3619,
#   'A': 2,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1271,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c8'),
#   'pos': 3917,
#   'sample_id': 'sc2-1001',
#   'dp': 1824,
#   'REFSKIP': 0,
#   'A': 1824,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519c9'),
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 11773,
#   'DEL': 0,
#   'dp': 11776,
#   'pos': 4148,
#   'sample_id': 'sc2-1001',
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ca'),
#   'T': 3,
#   'C': 15898,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 2,
#   'dp': 15905,
#   'sample_id': 'sc2-1001',
#   'pos': 4276,
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519cb'),
#   'G': 10438,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 2,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 4354,
#   'dp': 10440},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519cc'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4499,
#   'T': 0,
#   'G': 1,
#   'DEL': 0,
#   'pos': 4543,
#   'sample_id': 'sc2-1001',
#   'dp': 4500,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519cd'),
#   'pos': 4567,
#   'sample_id': 'sc2-1001',
#   'dp': 4129,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 5,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 4124,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ce'),
#   'T': 1,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 2488,
#   'pos': 4659,
#   'sample_id': 'sc2-1001',
#   'A': 2487,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519cf'),
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 1975,
#   'sample_id': 'sc2-1001',
#   'pos': 4891,
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 1974,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d0'),
#   'DEL': 0,
#   'G': 1249,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 4960,
#   'sample_id': 'sc2-1001',
#   'dp': 1250},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d1'),
#   'C': 65,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 4999,
#   'dp': 65,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d2'),
#   'G': 126,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 126,
#   'pos': 5062,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d3'),
#   'dp': 1610,
#   'sample_id': 'sc2-1001',
#   'pos': 5388,
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'C': 1610,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d4'),
#   'dp': 2041,
#   'sample_id': 'sc2-1001',
#   'pos': 5496,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'G': 2039,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d5'),
#   'T': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1893,
#   'G': 0,
#   'DEL': 0,
#   'dp': 1896,
#   'pos': 5512,
#   'sample_id': 'sc2-1001',
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d6'),
#   'dp': 6007,
#   'sample_id': 'sc2-1001',
#   'pos': 5629,
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'G': 6004,
#   'DEL': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d7'),
#   'T': 2,
#   'C': 7225,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 7229,
#   'sample_id': 'sc2-1001',
#   'pos': 5654,
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d8'),
#   'REFSKIP': 0,
#   'A': 1,
#   'pos': 5822,
#   'sample_id': 'sc2-1001',
#   'dp': 10967,
#   'DEL': 0,
#   'G': 0,
#   'C': 10963,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519d9'),
#   'C': 6738,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 5884,
#   'dp': 6739,
#   'REFSKIP': 0,
#   'A': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519da'),
#   'dp': 2739,
#   'pos': 5944,
#   'sample_id': 'sc2-1001',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2738,
#   'G': 1,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519db'),
#   'sample_id': 'sc2-1001',
#   'pos': 5949,
#   'dp': 2842,
#   'A': 2842,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519dc'),
#   'DEL': 1,
#   'G': 0,
#   'T': 0,
#   'C': 3860,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 3862,
#   'pos': 5986,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519dd'),
#   'REFSKIP': 0,
#   'A': 1,
#   'pos': 6033,
#   'sample_id': 'sc2-1001',
#   'dp': 4434,
#   'DEL': 1,
#   'G': 0,
#   'C': 4432,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519de'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4322,
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 4,
#   'sample_id': 'sc2-1001',
#   'pos': 6040,
#   'dp': 4326},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519df'),
#   'T': 15814,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 7,
#   'G': 0,
#   'DEL': 0,
#   'dp': 15823,
#   'pos': 6286,
#   'sample_id': 'sc2-1001',
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e0'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 3005,
#   'pos': 6568,
#   'sample_id': 'sc2-1001',
#   'DEL': 0,
#   'G': 0,
#   'T': 2,
#   'C': 3003,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e1'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 2729,
#   'pos': 6790,
#   'sample_id': 'sc2-1001',
#   'A': 2729,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e2'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 195,
#   'sample_id': 'sc2-1001',
#   'pos': 6941,
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 195},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e3'),
#   'dp': 216,
#   'sample_id': 'sc2-1001',
#   'pos': 6954,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 216,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e4'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 130,
#   'T': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 7029,
#   'dp': 130,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e5'),
#   'DEL': 0,
#   'G': 0,
#   'T': 4799,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'A': 2,
#   'REFSKIP': 0,
#   'dp': 4801,
#   'sample_id': 'sc2-1001',
#   'pos': 7386},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e6'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 15203,
#   'T': 0,
#   'A': 8,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 7834,
#   'dp': 15211},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e7'),
#   'sample_id': 'sc2-1001',
#   'pos': 7984,
#   'dp': 10227,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 10222,
#   'DEL': 0,
#   'G': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e8'),
#   'A': 2,
#   'REFSKIP': 0,
#   'dp': 5894,
#   'pos': 8290,
#   'sample_id': 'sc2-1001',
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 5892,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519e9'),
#   'dp': 938,
#   'pos': 8327,
#   'sample_id': 'sc2-1001',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 938,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ea'),
#   'DEL': 0,
#   'G': 0,
#   'T': 2,
#   'C': 1706,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 1708,
#   'sample_id': 'sc2-1001',
#   'pos': 8389},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519eb'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 881,
#   'G': 0,
#   'DEL': 0,
#   'dp': 881,
#   'sample_id': 'sc2-1001',
#   'pos': 8605,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ec'),
#   'sample_id': 'sc2-1001',
#   'pos': 8618,
#   'dp': 763,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 0,
#   'G': 763,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ed'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1419,
#   'G': 0,
#   'DEL': 0,
#   'dp': 1419,
#   'pos': 8814,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ee'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 7414,
#   'G': 0,
#   'DEL': 0,
#   'dp': 7414,
#   'pos': 8964,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ef'),
#   'A': 8,
#   'REFSKIP': 0,
#   'pos': 8983,
#   'sample_id': 'sc2-1001',
#   'dp': 10219,
#   'DEL': 0,
#   'G': 1,
#   'C': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 10207},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f0'),
#   'REFSKIP': 0,
#   'A': 17,
#   'pos': 9073,
#   'sample_id': 'sc2-1001',
#   'dp': 14834,
#   'DEL': 0,
#   'G': 3,
#   'C': 14810,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 4},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f1'),
#   'T': 0,
#   'C': 14299,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 3,
#   'dp': 14303,
#   'sample_id': 'sc2-1001',
#   'pos': 9118,
#   'REFSKIP': 0,
#   'A': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f2'),
#   'dp': 13456,
#   'sample_id': 'sc2-1001',
#   'pos': 9130,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'G': 13453,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f3'),
#   'C': 12942,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1,
#   'DEL': 0,
#   'G': 2,
#   'sample_id': 'sc2-1001',
#   'pos': 9133,
#   'dp': 12946,
#   'REFSKIP': 0,
#   'A': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f4'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2908,
#   'T': 0,
#   'G': 1,
#   'DEL': 0,
#   'pos': 9483,
#   'sample_id': 'sc2-1001',
#   'dp': 2925,
#   'A': 16,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f5'),
#   'G': 7732,
#   'DEL': 0,
#   'T': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 3,
#   'REFSKIP': 0,
#   'A': 2,
#   'dp': 7739,
#   'sample_id': 'sc2-1001',
#   'pos': 9526},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f6'),
#   'T': 4,
#   'C': 13683,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 13689,
#   'pos': 9679,
#   'sample_id': 'sc2-1001',
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f7'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 13197,
#   'G': 0,
#   'DEL': 0,
#   'dp': 13204,
#   'pos': 9693,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 7},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f8'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 5413,
#   'T': 0,
#   'A': 1,
#   'REFSKIP': 0,
#   'pos': 9811,
#   'sample_id': 'sc2-1001',
#   'dp': 5414},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519f9'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 19322,
#   'T': 1,
#   'G': 5,
#   'DEL': 1,
#   'pos': 10188,
#   'sample_id': 'sc2-1001',
#   'dp': 19329,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519fa'),
#   'dp': 19919,
#   'pos': 10339,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 1,
#   'T': 19913,
#   'C': 4,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519fb'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 9005,
#   'sample_id': 'sc2-1001',
#   'pos': 10582,
#   'DEL': 0,
#   'G': 1,
#   'T': 1,
#   'C': 9003,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519fc'),
#   'A': 1,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 10818,
#   'dp': 1304,
#   'G': 2,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1301,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519fd'),
#   'T': 6380,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 1,
#   'dp': 6383,
#   'sample_id': 'sc2-1001',
#   'pos': 11025,
#   'REFSKIP': 0,
#   'A': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519fe'),
#   'G': 17740,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2,
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 3,
#   'sample_id': 'sc2-1001',
#   'pos': 11287,
#   'dp': 17745},
#  {'_id': ObjectId('6294b9ffc3d5743c5c7519ff'),
#   'A': 4,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 11288,
#   'dp': 17741,
#   'G': 12,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 5,
#   'T': 17720},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a00'),
#   'DEL': 0,
#   'G': 3,
#   'C': 11855,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 3,
#   'A': 2,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 11497,
#   'dp': 11863},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a01'),
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 11967,
#   'sample_id': 'sc2-1001',
#   'pos': 11540,
#   'DEL': 0,
#   'G': 11964,
#   'T': 2,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a02'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4102,
#   'A': 1,
#   'REFSKIP': 0,
#   'dp': 4103,
#   'pos': 11758,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a03'),
#   'REFSKIP': 0,
#   'A': 28409,
#   'pos': 12162,
#   'sample_id': 'sc2-1001',
#   'dp': 28433,
#   'G': 11,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'T': 12},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a04'),
#   'pos': 12513,
#   'sample_id': 'sc2-1001',
#   'dp': 19728,
#   'A': 6,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 19715,
#   'T': 6,
#   'G': 1,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a05'),
#   'dp': 19881,
#   'sample_id': 'sc2-1001',
#   'pos': 12514,
#   'A': 7,
#   'REFSKIP': 0,
#   'T': 4,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'G': 19869,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a06'),
#   'T': 11755,
#   'C': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 11761,
#   'sample_id': 'sc2-1001',
#   'pos': 12766,
#   'A': 4,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a07'),
#   'G': 2,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4932,
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 12970,
#   'dp': 4934},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a08'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 13458,
#   'sample_id': 'sc2-1001',
#   'dp': 4388,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4386,
#   'T': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a09'),
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 13665,
#   'dp': 1186,
#   'DEL': 0,
#   'G': 0,
#   'C': 1186,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a0a'),
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'A': 1784,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 13715,
#   'dp': 1784},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a0b'),
#   'DEL': 0,
#   'G': 10605,
#   'T': 0,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 10607,
#   'sample_id': 'sc2-1001',
#   'pos': 13993},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a0c'),
#   'T': 2,
#   'C': 18714,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 18717,
#   'pos': 14120,
#   'sample_id': 'sc2-1001',
#   'A': 1,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a0d'),
#   'REFSKIP': 0,
#   'A': 9,
#   'sample_id': 'sc2-1001',
#   'pos': 14265,
#   'dp': 15725,
#   'G': 2,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 15713,
#   'T': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a0e'),
#   'dp': 15020,
#   'sample_id': 'sc2-1001',
#   'pos': 14322,
#   'REFSKIP': 0,
#   'A': 7,
#   'T': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 15006,
#   'G': 0,
#   'DEL': 4},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a0f'),
#   'sample_id': 'sc2-1001',
#   'pos': 14408,
#   'dp': 17969,
#   'A': 4,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'T': 17961,
#   'G': 2,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a10'),
#   'DEL': 0,
#   'G': 1,
#   'C': 10176,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 2,
#   'sample_id': 'sc2-1001',
#   'pos': 14599,
#   'dp': 10179},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a11'),
#   'DEL': 0,
#   'G': 7,
#   'C': 17829,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 2,
#   'REFSKIP': 0,
#   'A': 3,
#   'pos': 14676,
#   'sample_id': 'sc2-1001',
#   'dp': 17841},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a12'),
#   'pos': 15096,
#   'sample_id': 'sc2-1001',
#   'dp': 2826,
#   'A': 2,
#   'REFSKIP': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 2824,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a13'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 6928,
#   'sample_id': 'sc2-1001',
#   'pos': 15279,
#   'G': 2,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 6926},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a14'),
#   'A': 1,
#   'REFSKIP': 0,
#   'pos': 15324,
#   'sample_id': 'sc2-1001',
#   'dp': 8811,
#   'G': 2,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 8807,
#   'T': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a15'),
#   'DEL': 1,
#   'G': 3,
#   'C': 10166,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1,
#   'A': 1,
#   'REFSKIP': 0,
#   'pos': 15540,
#   'sample_id': 'sc2-1001',
#   'dp': 10172},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a16'),
#   'REFSKIP': 0,
#   'A': 2,
#   'dp': 15502,
#   'sample_id': 'sc2-1001',
#   'pos': 15579,
#   'DEL': 0,
#   'G': 2,
#   'T': 1,
#   'C': 15497,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a17'),
#   'pos': 15720,
#   'sample_id': 'sc2-1001',
#   'dp': 20618,
#   'REFSKIP': 0,
#   'A': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 20610,
#   'T': 5,
#   'G': 1,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a18'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 17310,
#   'sample_id': 'sc2-1001',
#   'pos': 15766,
#   'G': 17306,
#   'DEL': 0,
#   'T': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a19'),
#   'DEL': 0,
#   'G': 13549,
#   'T': 8,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 13557,
#   'pos': 16075,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a1a'),
#   'T': 4467,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 4467,
#   'sample_id': 'sc2-1001',
#   'pos': 16176,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a1b'),
#   'A': 1090,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 16242,
#   'dp': 1090,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a1c'),
#   'sample_id': 'sc2-1001',
#   'pos': 16262,
#   'dp': 1172,
#   'A': 1171,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 1,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a1d'),
#   'dp': 1007,
#   'pos': 16396,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 1007,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a1e'),
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 16564,
#   'dp': 3594,
#   'DEL': 0,
#   'G': 3594,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a1f'),
#   'C': 3625,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 16616,
#   'dp': 3626,
#   'A': 1,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a20'),
#   'pos': 16843,
#   'sample_id': 'sc2-1001',
#   'dp': 1650,
#   'A': 2,
#   'REFSKIP': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1,
#   'DEL': 0,
#   'G': 1647},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a21'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 3,
#   'DEL': 0,
#   'G': 1,
#   'pos': 16889,
#   'sample_id': 'sc2-1001',
#   'dp': 2192,
#   'A': 2188,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a22'),
#   'G': 2100,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 2100,
#   'pos': 16912,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a23'),
#   'dp': 2152,
#   'sample_id': 'sc2-1001',
#   'pos': 16985,
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2152,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a24'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2273,
#   'G': 0,
#   'DEL': 0,
#   'dp': 2273,
#   'pos': 17010,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a25'),
#   'dp': 2186,
#   'sample_id': 'sc2-1001',
#   'pos': 17019,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 2186},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a26'),
#   'pos': 17304,
#   'sample_id': 'sc2-1001',
#   'dp': 26151,
#   'REFSKIP': 0,
#   'A': 7,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 26133,
#   'T': 5,
#   'G': 6,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a27'),
#   'A': 3,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 17571,
#   'dp': 7731,
#   'DEL': 2,
#   'G': 7,
#   'C': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 7717},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a28'),
#   'T': 2,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 2,
#   'G': 7755,
#   'dp': 7761,
#   'sample_id': 'sc2-1001',
#   'pos': 17572,
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a29'),
#   'G': 4,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 1,
#   'A': 8165,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 17615,
#   'dp': 8170},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a2a'),
#   'A': 1,
#   'REFSKIP': 0,
#   'dp': 8224,
#   'pos': 18032,
#   'sample_id': 'sc2-1001',
#   'G': 0,
#   'DEL': 0,
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 8222},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a2b'),
#   'A': 2,
#   'REFSKIP': 0,
#   'dp': 8293,
#   'sample_id': 'sc2-1001',
#   'pos': 18164,
#   'DEL': 0,
#   'G': 1,
#   'T': 8289,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a2c'),
#   'T': 6,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2,
#   'G': 24943,
#   'DEL': 0,
#   'dp': 24955,
#   'sample_id': 'sc2-1001',
#   'pos': 18462,
#   'REFSKIP': 0,
#   'A': 4},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a2d'),
#   'DEL': 3,
#   'G': 1,
#   'C': 22546,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 2,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 18555,
#   'sample_id': 'sc2-1001',
#   'dp': 22552},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a2e'),
#   'T': 1,
#   'C': 22548,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 2,
#   'dp': 22555,
#   'pos': 18557,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 4},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a2f'),
#   'A': 3,
#   'REFSKIP': 0,
#   'dp': 23409,
#   'pos': 18877,
#   'sample_id': 'sc2-1001',
#   'G': 2,
#   'DEL': 2,
#   'T': 2,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 23400},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a30'),
#   'DEL': 0,
#   'G': 16524,
#   'T': 5,
#   'C': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'A': 4,
#   'REFSKIP': 0,
#   'dp': 16536,
#   'sample_id': 'sc2-1001',
#   'pos': 18937},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a31'),
#   'C': 193,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 19524,
#   'dp': 193,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a32'),
#   'sample_id': 'sc2-1001',
#   'pos': 19560,
#   'dp': 129,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 129,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a33'),
#   'T': 0,
#   'C': 381,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 381,
#   'sample_id': 'sc2-1001',
#   'pos': 19955,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a34'),
#   'G': 0,
#   'DEL': 0,
#   'T': 256,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 256,
#   'pos': 20186,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a35'),
#   'G': 449,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 0,
#   'A': 1,
#   'REFSKIP': 0,
#   'pos': 20247,
#   'sample_id': 'sc2-1001',
#   'dp': 450},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a36'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 536,
#   'pos': 20275,
#   'sample_id': 'sc2-1001',
#   'dp': 536,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a37'),
#   'T': 804,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 804,
#   'pos': 20407,
#   'sample_id': 'sc2-1001',
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a38'),
#   'dp': 814,
#   'pos': 20408,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 813,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a39'),
#   'T': 12894,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 12899,
#   'sample_id': 'sc2-1001',
#   'pos': 20661,
#   'REFSKIP': 0,
#   'A': 5},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a3a'),
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 21473,
#   'pos': 20940,
#   'sample_id': 'sc2-1001',
#   'DEL': 0,
#   'G': 21472,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a3b'),
#   'REFSKIP': 0,
#   'A': 9,
#   'pos': 21015,
#   'sample_id': 'sc2-1001',
#   'dp': 20106,
#   'G': 1,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 3,
#   'T': 20093},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a3c'),
#   'G': 1,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 1,
#   'A': 6558,
#   'REFSKIP': 0,
#   'pos': 21137,
#   'sample_id': 'sc2-1001',
#   'dp': 6561},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a3d'),
#   'dp': 210,
#   'pos': 21255,
#   'sample_id': 'sc2-1001',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'C': 210,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a3e'),
#   'dp': 229,
#   'sample_id': 'sc2-1001',
#   'pos': 21304,
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'C': 229,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a3f'),
#   'dp': 574,
#   'pos': 21549,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 574,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a40'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 577,
#   'sample_id': 'sc2-1001',
#   'pos': 21571,
#   'G': 0,
#   'DEL': 0,
#   'T': 577,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a41'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 498,
#   'sample_id': 'sc2-1001',
#   'pos': 21614,
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 498},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a42'),
#   'T': 1,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 5078,
#   'dp': 5080,
#   'sample_id': 'sc2-1001',
#   'pos': 21718,
#   'REFSKIP': 0,
#   'A': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a43'),
#   'DEL': 0,
#   'G': 1,
#   'C': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 6398,
#   'A': 1,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 21748,
#   'dp': 6403},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a44'),
#   'G': 0,
#   'DEL': 6,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 6895,
#   'dp': 6901,
#   'pos': 21764,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a45'),
#   'G': 0,
#   'DEL': 6753,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 149,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 21765,
#   'sample_id': 'sc2-1001',
#   'dp': 6902},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a46'),
#   'A': 1,
#   'REFSKIP': 0,
#   'dp': 10118,
#   'pos': 21855,
#   'sample_id': 'sc2-1001',
#   'DEL': 2,
#   'G': 1,
#   'T': 0,
#   'C': 10114,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a47'),
#   'A': 1,
#   'REFSKIP': 0,
#   'pos': 21990,
#   'sample_id': 'sc2-1001',
#   'dp': 4150,
#   'DEL': 2,
#   'G': 2,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 4145},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a48'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 21991,
#   'sample_id': 'sc2-1001',
#   'dp': 4555,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 4555},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a49'),
#   'C': 3178,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'pos': 22006,
#   'sample_id': 'sc2-1001',
#   'dp': 3179,
#   'REFSKIP': 0,
#   'A': 1},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a4a'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 532,
#   'DEL': 0,
#   'G': 0,
#   'pos': 22016,
#   'sample_id': 'sc2-1001',
#   'dp': 532,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a4b'),
#   'G': 1,
#   'DEL': 1,
#   'T': 1242,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 1245,
#   'pos': 22227,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a4c'),
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1125,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 22238,
#   'dp': 1125},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a4d'),
#   'dp': 137,
#   'sample_id': 'sc2-1001',
#   'pos': 22329,
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 137,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a4e'),
#   'dp': 173,
#   'pos': 22346,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 173,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a4f'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 215,
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 22377,
#   'sample_id': 'sc2-1001',
#   'dp': 215},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a50'),
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 4492,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 22843,
#   'dp': 4492},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a51'),
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 2111,
#   'dp': 2113,
#   'sample_id': 'sc2-1001',
#   'pos': 22992,
#   'REFSKIP': 0,
#   'A': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a52'),
#   'DEL': 0,
#   'G': 0,
#   'T': 1799,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 1801,
#   'pos': 23017,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a53'),
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 1945,
#   'sample_id': 'sc2-1001',
#   'pos': 23063,
#   'A': 1944,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a54'),
#   'sample_id': 'sc2-1001',
#   'pos': 23271,
#   'dp': 11797,
#   'A': 3,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 11794,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a55'),
#   'dp': 11041,
#   'sample_id': 'sc2-1001',
#   'pos': 23401,
#   'A': 4,
#   'REFSKIP': 0,
#   'T': 3,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 11033},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a56'),
#   'REFSKIP': 0,
#   'A': 1,
#   'dp': 11056,
#   'pos': 23403,
#   'sample_id': 'sc2-1001',
#   'G': 11052,
#   'DEL': 0,
#   'T': 3,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a57'),
#   'dp': 7958,
#   'pos': 23430,
#   'sample_id': 'sc2-1001',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 7958,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a58'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0,
#   'T': 1,
#   'G': 3,
#   'DEL': 1,
#   'pos': 23524,
#   'sample_id': 'sc2-1001',
#   'dp': 2801,
#   'A': 2796,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a59'),
#   'pos': 23604,
#   'sample_id': 'sc2-1001',
#   'dp': 5643,
#   'A': 2,
#   'REFSKIP': 0,
#   'C': 5641,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a5a'),
#   'dp': 6593,
#   'pos': 23709,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'C': 6593,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a5b'),
#   'A': 1,
#   'REFSKIP': 0,
#   'dp': 4804,
#   'pos': 23758,
#   'sample_id': 'sc2-1001',
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 4803,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a5c'),
#   'pos': 23896,
#   'sample_id': 'sc2-1001',
#   'dp': 904,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 904,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a5d'),
#   'dp': 906,
#   'pos': 23897,
#   'sample_id': 'sc2-1001',
#   'REFSKIP': 0,
#   'A': 1,
#   'T': 0,
#   'C': 905,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a5e'),
#   'REFSKIP': 0,
#   'A': 3,
#   'dp': 3569,
#   'pos': 24109,
#   'sample_id': 'sc2-1001',
#   'DEL': 0,
#   'G': 0,
#   'T': 1,
#   'C': 3565,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a5f'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 8273,
#   'pos': 24378,
#   'sample_id': 'sc2-1001',
#   'G': 3,
#   'DEL': 0,
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 8269},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a60'),
#   'DEL': 0,
#   'G': 0,
#   'T': 5244,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 5245,
#   'pos': 24506,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a61'),
#   'DEL': 0,
#   'G': 11984,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1,
#   'A': 1,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 24757,
#   'dp': 11986},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a62'),
#   'C': 6,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 14,
#   'DEL': 0,
#   'G': 14202,
#   'pos': 24781,
#   'sample_id': 'sc2-1001',
#   'dp': 14224,
#   'REFSKIP': 0,
#   'A': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a63'),
#   'A': 2,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 24784,
#   'dp': 15521,
#   'G': 3,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 15514,
#   'T': 2},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a64'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 21514,
#   'T': 5,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 24865,
#   'dp': 21519},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a65'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2,
#   'T': 3,
#   'G': 19026,
#   'DEL': 0,
#   'pos': 24914,
#   'sample_id': 'sc2-1001',
#   'dp': 19033,
#   'A': 2,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a66'),
#   'sample_id': 'sc2-1001',
#   'pos': 25207,
#   'dp': 4461,
#   'A': 1,
#   'REFSKIP': 0,
#   'C': 4460,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a67'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 3441,
#   'sample_id': 'sc2-1001',
#   'pos': 25244,
#   'DEL': 0,
#   'G': 3440,
#   'T': 0,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a68'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 2022,
#   'sample_id': 'sc2-1001',
#   'pos': 25282,
#   'DEL': 0,
#   'G': 0,
#   'T': 11,
#   'C': 2011,
#   'sample_oid': '6294b9fec3d5743c5c751931'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a69'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 1437,
#   'pos': 25298,
#   'sample_id': 'sc2-1001',
#   'G': 1437,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a6a'),
#   'dp': 10767,
#   'sample_id': 'sc2-1001',
#   'pos': 25348,
#   'REFSKIP': 0,
#   'A': 1,
#   'T': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1,
#   'G': 10764,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a6b'),
#   'dp': 18383,
#   'sample_id': 'sc2-1001',
#   'pos': 25459,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 6,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 3,
#   'G': 18374,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a6c'),
#   'dp': 18000,
#   'pos': 25505,
#   'sample_id': 'sc2-1001',
#   'A': 17986,
#   'REFSKIP': 0,
#   'T': 5,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 8},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a6d'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4,
#   'T': 2,
#   'G': 2,
#   'DEL': 0,
#   'pos': 25506,
#   'sample_id': 'sc2-1001',
#   'dp': 17969,
#   'REFSKIP': 0,
#   'A': 17961},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a6e'),
#   'DEL': 0,
#   'G': 14244,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'A': 1,
#   'REFSKIP': 0,
#   'pos': 25563,
#   'sample_id': 'sc2-1001',
#   'dp': 14245},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a6f'),
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 4402,
#   'T': 0,
#   'G': 2,
#   'DEL': 0,
#   'pos': 25638,
#   'sample_id': 'sc2-1001',
#   'dp': 4407,
#   'REFSKIP': 0,
#   'A': 3},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a70'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 1014,
#   'pos': 25710,
#   'sample_id': 'sc2-1001',
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1014},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a71'),
#   'sample_id': 'sc2-1001',
#   'pos': 25728,
#   'dp': 1314,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 1,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 1311,
#   'DEL': 2,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a72'),
#   'T': 0,
#   'C': 1339,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'DEL': 0,
#   'G': 0,
#   'dp': 1340,
#   'pos': 25731,
#   'sample_id': 'sc2-1001',
#   'A': 1,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a73'),
#   'DEL': 0,
#   'G': 1243,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 1243,
#   'pos': 25767,
#   'sample_id': 'sc2-1001'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a74'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 1305,
#   'sample_id': 'sc2-1001',
#   'pos': 25785,
#   'dp': 1305,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a75'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 1292,
#   'T': 6,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1001',
#   'pos': 25791,
#   'dp': 1298},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a76'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 2,
#   'G': 750,
#   'DEL': 0,
#   'dp': 752,
#   'sample_id': 'sc2-1001',
#   'pos': 25906,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a77'),
#   'pos': 25996,
#   'sample_id': 'sc2-1001',
#   'dp': 18,
#   'REFSKIP': 0,
#   'A': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0,
#   'DEL': 0,
#   'G': 18},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a78'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 20,
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 26013,
#   'sample_id': 'sc2-1001',
#   'dp': 20},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a79'),
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 26028,
#   'sample_id': 'sc2-1001',
#   'dp': 22,
#   'DEL': 0,
#   'G': 0,
#   'C': 22,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a7a'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 25,
#   'pos': 26038,
#   'sample_id': 'sc2-1001',
#   'G': 0,
#   'DEL': 0,
#   'T': 25,
#   'sample_oid': '6294b9fec3d5743c5c751931',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751a7b'),
#   'T': 0,
#   'C': 0,
# ...
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 5822,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d3f'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 5884,
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d40'),
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 5944,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d41'),
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 0,
#   'pos': 5949,
#   'sample_id': 'sc2-1004'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d42'),
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 5986,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d43'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 6033,
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d44'),
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 6040,
#   'dp': 0,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d45'),
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 6286},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d46'),
#   'sample_id': 'sc2-1004',
#   'pos': 6568,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d47'),
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 6790,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d48'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 6941,
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d49'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 6954,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d4a'),
#   'dp': 0,
#   'pos': 7029,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d4b'),
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 7386,
#   'dp': 0,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d4c'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 0,
#   'pos': 7834,
#   'sample_id': 'sc2-1004'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d4d'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 0,
#   'pos': 7984,
#   'sample_id': 'sc2-1004'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d4e'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 0,
#   'pos': 8290,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d4f'),
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 8327,
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d50'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 8389,
#   'sample_id': 'sc2-1004',
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d51'),
#   'pos': 8605,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d52'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 8618},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d53'),
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 8814,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d54'),
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 8964,
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d55'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 8983,
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d56'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 9073,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d57'),
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 9118},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d58'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'pos': 9130,
#   'sample_id': 'sc2-1004'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d59'),
#   'pos': 9133,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d5a'),
#   'dp': 0,
#   'pos': 9483,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d5b'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 9526,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d5c'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 9679,
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d5d'),
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0,
#   'dp': 0,
#   'pos': 9693,
#   'sample_id': 'sc2-1004',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d5e'),
#   'sample_id': 'sc2-1004',
#   'pos': 9811,
#   'dp': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d5f'),
#   'pos': 10188,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d60'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 10339,
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d61'),
#   'dp': 0,
#   'pos': 10582,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d62'),
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0,
#   'dp': 0,
#   'pos': 10818,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d63'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 0,
#   'pos': 11025,
#   'sample_id': 'sc2-1004',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d64'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 0,
#   'pos': 11287,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d65'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 0,
#   'pos': 11288,
#   'sample_id': 'sc2-1004',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d66'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'pos': 11497,
#   'sample_id': 'sc2-1004',
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d67'),
#   'REFSKIP': 0,
#   'A': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 11540,
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d68'),
#   'dp': 0,
#   'pos': 11758,
#   'sample_id': 'sc2-1004',
#   'REFSKIP': 0,
#   'A': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d69'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 12162,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d6a'),
#   'pos': 12513,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d6b'),
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 12514,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d6c'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 12766,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d6d'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 12970,
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d6e'),
#   'sample_id': 'sc2-1004',
#   'pos': 13458,
#   'dp': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d6f'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 13665},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d70'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 13715,
#   'sample_id': 'sc2-1004',
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d71'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 13993,
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d72'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 14120,
#   'sample_id': 'sc2-1004',
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d73'),
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 14265,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d74'),
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 14322,
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d75'),
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 14408,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d76'),
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'pos': 14599,
#   'sample_id': 'sc2-1004'},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d77'),
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 14676},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d78'),
#   'REFSKIP': 0,
#   'A': 0,
#   'dp': 0,
#   'pos': 15096,
#   'sample_id': 'sc2-1004',
#   'G': 0,
#   'DEL': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d79'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 15279,
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d7a'),
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'DEL': 0,
#   'G': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 15324,
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d7b'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 0,
#   'pos': 15540,
#   'sample_id': 'sc2-1004',
#   'REFSKIP': 0,
#   'A': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d7c'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 15579,
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d7d'),
#   'dp': 0,
#   'pos': 15720,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0,
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d7e'),
#   'sample_id': 'sc2-1004',
#   'pos': 15766,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d7f'),
#   'sample_id': 'sc2-1004',
#   'pos': 16075,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d80'),
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'G': 0,
#   'DEL': 0,
#   'pos': 16176,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d81'),
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'DEL': 0,
#   'G': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 16242,
#   'dp': 0,
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d82'),
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 16262,
#   'sample_id': 'sc2-1004',
#   'dp': 0,
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d83'),
#   'DEL': 0,
#   'G': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 16396,
#   'sample_id': 'sc2-1004',
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d84'),
#   'T': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'G': 0,
#   'DEL': 0,
#   'dp': 0,
#   'pos': 16564,
#   'sample_id': 'sc2-1004',
#   'A': 0,
#   'REFSKIP': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d85'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'A': 0,
#   'REFSKIP': 0,
#   'pos': 16616,
#   'sample_id': 'sc2-1004',
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d86'),
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0,
#   'REFSKIP': 0,
#   'A': 0,
#   'pos': 16843,
#   'sample_id': 'sc2-1004',
#   'dp': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d87'),
#   'A': 0,
#   'REFSKIP': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 16889,
#   'dp': 0,
#   'G': 0,
#   'DEL': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'C': 0,
#   'T': 0},
#  {'_id': ObjectId('6294b9ffc3d5743c5c751d88'),
#   'DEL': 0,
#   'G': 0,
#   'T': 0,
#   'C': 0,
#   'sample_oid': '6294b9fec3d5743c5c751934',
#   'A': 0,
#   'REFSKIP': 0,
#   'dp': 0,
#   'sample_id': 'sc2-1004',
#   'pos': 16912},
#  ...]

# %%
df = pd.DataFrame()
col_name = ''
col = []
index = []
for ele in depth:
    if ele['sample_id'] != col_name:
        df[col_name] = col
        col_name = ele['sample_id']
        col = []
        index = []
    col.extend([ele['A'], ele['T'], ele['C'], ele['G']])
    index.extend([f'{ele["pos"]}_A', f'{ele["pos"]}_T', f'{ele["pos"]}_C', f'{ele["pos"]}_G'])
    
df.index = index

# %%
df.iloc[:,1:]
# Out:
#          sc2-1001  sc2-1002  sc2-1003  sc2-1004  sc2-1005  sc2-1006  sc2-1007  \
# 35_A            0         0         0         0         0         0         0
# 35_T            0         0         0         0         0         0         0
# 35_C            0         0         0         0         0         0         0
# 35_G            0         0         0         0         0         0         0
# 103_A           0         0         0         0         0         0         0
# ...           ...       ...       ...       ...       ...       ...       ...
# 29767_G         2         0         0         0         0         0         0
# 29811_A         0         0         0         0         0         0         0
# 29811_T      1795       796         0         0         0         0         0
# 29811_C         1         0         0         0         0         0         0
# 29811_G         0         0         0         0         0         0         0
#
#          sc2-1008  sc2-1009  sc2-1010  ...  sc2-1046  sc2-1047  sc2-1048  \
# 35_A           26         0         1  ...        14        60        74
# 35_T            0         0         0  ...         0         2         1
# 35_C            0         0         0  ...         0         1         0
# 35_G            0         0         0  ...         0         1         0
# 103_A           0         0         1  ...         0         1         0
# ...           ...       ...       ...  ...       ...       ...       ...
# 29767_G         7         0         8  ...         2         2         7
# 29811_A         1         0         1  ...         0         1         0
# 29811_T      3452       920      3392  ...      3598      3598      3584
# 29811_C         1         0         1  ...         0         1         1
# 29811_G         0         0         0  ...         0         0         0
#
#          sc2-1049  sc2-1050  sc2-1051  sc2-1052  sc2-1053  sc2-1054  sc2-1055
# 35_A           49        18        19        24         0         0        11
# 35_T            0         0         0         0         0         0         0
# 35_C            0         0         0         0         0         0         0
# 35_G            0         0         0         0         0         0         0
# 103_A           0         0         0         1         0         0         0
# ...           ...       ...       ...       ...       ...       ...       ...
# 29767_G         4         1         5         3         0         4         2
# 29811_A         1         0         0         1         0         0         1
# 29811_T      3939      3508      3225      3029       945      2358      3708
# 29811_C         0         0         1         0         0         0         1
# 29811_G         0         1         0         1         0         0         0
#
# [1160 rows x 55 columns]
